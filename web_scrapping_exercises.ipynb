# %% [markdown]
# # Main things we need to understand
#     Rules of Web scraping
#     Limiation of Web Scraping
#     Basic HTML ans CSS
#
# # Before starting this section there are some rules which is important to follow:
# As a respectful person try to get permission to scrape. Otherwise your IP address may be blocked.
# If you make too many scraping attempts or requests then it may be your IP Address could get blocked!
# There are some professional websites who is automatically block scraping software.
#
# # Limitations of Web Scraping
# The second thing I want to talk about are the limitaion of web scraping and i general every website is unique, which means they have unique id or url or script is unique. And keep in mind that any slight change or update to a Web site may completely break your web scraping script.
#
# # Web Scraping
# Web scraping is that when you want to extract some of the important data from the websites. When APIs are not available usually the ideal way of picking up some of the data through API which is recommended and which is like the best way of doing the things, but sometime it’s not actually its little gray area because web scarping is not legally allowed on most of the web site.
# # What is web scraping?
# Web scraping is a general term for method or techniques which involving automating the gathering the large amount data and information from a web page. As you can imagine, there’s often web sites that have information that you want to use for some other project. However, actually going in and copying and pasting the information yourself would just take too long to realistically possible.
# In order to web script of Python, where we first need to understand are the basic concepts of how a website works
# Basic components of a website HTML, CSS.
#
# HTML stand for Hypertext Markup Language and it is the frame of any page
# Why scrap the web?
# Is it legal to do web scrapping?
# Web scrapping with python
# Grabbing the title of a page

# %% [markdown]
# # Web Scraping Exercises

# %% [markdown]
# Task: Import any libraries you think you'll need to scrape a website.
# So we are going to import rewueste and we are also going to import Beautifulsoup library. so how we can proceed with that the first thing you have to make the request to the website from where you want to do parsing or may be kind or scraping. let's get started. Go ahead and give a go at the anaconda prompt. and what we need to do here is we to install three libraries. just make sure they are installed. if you are using Anaconda as your main setup, you should be able to use conda install. if not , you can always use pip install as well. "pip install requests" for beautiful soup "pip install beautifulsoup4"

# %%
import requests

# %%
import bs4

# %% [markdown]
# Task: use requests library and BeautifulSoup to connect to http://quotes.toscrape.com/ and get the HTML text from the homepage. Let just create an object variable res and res is just make a request.( This is the first step )

# %%
res = requests.get("http://quotes.toscrape.com/")

# %% [markdown]
# If you checkout the res it's obeject of request which storing all of things.

# %%
type(res)
# Out:
# requests.models.Response

# %% [markdown]
# So the next thing if you check the res.text and check it out it is showing entair web page.

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>\n        <
# ...

# %% [markdown]
# Task: Get the names of all the authors on the page. now we are going to creating another object from the Beautiful soup is soup. Now this beautiful soup take two parametere the first is just we have created the object res.text and the second one how  you want to structur your data. there are lot of structure beautiful soup support like HTML parsal, lxml and i am using lxml here. To install lxml write this line in your command prompt or if you are using anaconda then anaconda prompt: "pip install lxml"
#
# So we can say soup.select, and this is where you can actually grab things from this html document.

# %%
Soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
type(Soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# this is the very importent step now you can do anything what is mention in the documention of beautiful soup.

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %% [markdown]
# for example we just want to extract the title of the web page or p tag then select the paragraph tag. if you want to grab the actual text then in this case, i need to grab the first item of this. So let's go ahead and grab first item we get the string and once i have that, i can use the getText() method, which just returns back the stream.

# %%
Soup.select("title")
# Out:
# [<title>Quotes to Scrape</title>]

# %%
Soup.select("title")[0].getText()
# Out:
# 'Quotes to Scrape'

# %%
Soup.select("p")
# Out:
# [<p>
#  <a href="/login">Login</a>
#  </p>,
#  <p class="text-muted">
#                  Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#  </p>,
#  <p class="copyright">
#                  Made with <span class="sh-red">❤</span> by <a href="https://scrapinghub.com">Scrapinghub</a>
#  </p>]

# %%
Soup.select("p")[0]
# Out:
# <p>
# <a href="/login">Login</a>
# </p>

# %% [markdown]
# if we check the type of this use this code. it's actually a tag.

# %%
type(Soup.select("p")[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# # Grabbing All Elements of a class

# %% [markdown]
# Now we are going to make a request as res and pass on the full URl whcih we choose for grabbing. and then we make a soup out of the text from that request.

# %%
res = requests.get("https://en.wikipedia.org/wiki/Grace_Hopper")

# %%
soup = bs4.BeautifulSoup(res.text, "lxml") # we check the soup

# %%
soup # it's gonna be quite large. because there's a lot of stuff in that Wikipedia article.
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Grace Hopper - Wikipedia</title>
# ...

# %% [markdown]
# So here what i want to do is a soup thrught select. and then passing the appropriate string code.

# %%
soup.select('.toctext')
# Out:
# [<span class="toctext">Early life and education</span>,
#  <span class="toctext">Career</span>,
#  <span class="toctext">World War II</span>,
#  <span class="toctext">UNIVAC</span>,
#  <span class="toctext">COBOL</span>,
#  <span class="toctext">Standards</span>,
#  <span class="toctext">Retirement</span>,
#  <span class="toctext">Post-retirement</span>,
#  <span class="toctext">Anecdotes</span>,
#  <span class="toctext">Death</span>,
#  <span class="toctext">Dates of rank</span>,
#  <span class="toctext">Awards and honors</span>,
#  <span class="toctext">Military awards</span>,
#  <span class="toctext">Other awards</span>,
#  <span class="toctext">Legacy</span>,
#  <span class="toctext">Places</span>,
#  <span class="toctext">Programs</span>,
#  <span class="toctext">In popular culture</span>,
#  <span class="toctext">Grace Hopper Celebration of Women in Computing</span>,
#  <span class="toctext">Notes</span>,
#  <span class="toctext">Obituary notices</span>,
# ...

# %% [markdown]
# let's imagine that i actually just want this text "Early life and education", not the span in class call So recall, we can actually then loop through this and grab the text attribute from these items.

# %%
first_item = soup.select('.toctext')[0]

# %%
first_item
# Out:
# <span class="toctext">Early life and education</span>

# %%
first_item.text
# Out:
# 'Early life and education'

# %%
for item in soup.select('.toctext'):
    print(item.text)
# Out:
# Early life and education
# Career
# World War II
# UNIVAC
# COBOL
# Standards
# Retirement
# Post-retirement
# Anecdotes
# Death
# Dates of rank
# Awards and honors
# Military awards
# Other awards
# Legacy
# Places
# Programs
# In popular culture
# Grace Hopper Celebration of Women in Computing
# Notes
# Obituary notices
# See also
# References
# Further reading
# External links

# %% [markdown]
# # Grabbing an Image

# %% [markdown]
# Now that we understand how to grab text information based on tags and element names, let's explore how to grab images from a website. Beautiful Soup can scan a page, locate the <img> tage and grab these URLs. Then we can download the URLs as images and write then to the commputer.
#
# Note: You should always check copyright permission before downloading and using an image from a website.

# %% [markdown]
# I'm going to be using the article on Wikipedia for Deep Blue, which is a very famouse chess playing computer and we are going to do it, see if we can grab the images off this particular Web page.

# %%
res =requests.get("http://goeduhub.com/10498/social-distancing-detection-python-machine-learning-learning?show=10498#q10498")

# %%
soup =bs4.BeautifulSoup(res.text,"lxml")

# %%
soup.select('img')
# Out:
# [<img src="https://www.pinclipart.com/picdir/middle/395-3959661_youtube-subscribe-chanell-png-image-youtube-subscribe-logo.png" width="100"/>,
#  <img alt="Goeduhub Technologies" height="250" src="https://www.goeduhub.com/goeduhub.PNG" width="250"/>,
#  <img alt="" class="qa-avatar-image" height="34" src="../?qa=image&amp;qa_blobid=16918453476815569842&amp;qa_size=50" width="34"/>,
#  <img alt="" class="qa-avatar-image" height="34" src="../?qa=image&amp;qa_blobid=16918453476815569842&amp;qa_size=40" width="34"/>,
#  <img alt="Social Distancing detector" src="https://www.goeduhub.com/?qa=blob&amp;qa_blobid=3615566808426142899" style="height:337px; width:600px"/>,
#  <img alt="" class="qa-avatar-image" height="34" src="../?qa=image&amp;qa_blobid=16918453476815569842&amp;qa_size=40" width="34"/>,
#  <img alt="" src="https://www.goeduhub.com/?qa=blob&amp;qa_blobid=7873556312240135549"/>,
# ...

# %% [markdown]
# <img src="https://www.goeduhub.com/?qa=blob&amp;qa_blobid=3615566808426142899">

# %% [markdown]
# <img src ="https://www.goeduhub.com/?qa=blob&qa_blobid=7873556312240135549">

# %%
soup.select("img")[0]
# Out:
# <img src="https://www.pinclipart.com/picdir/middle/395-3959661_youtube-subscribe-chanell-png-image-youtube-subscribe-logo.png" width="100"/>

# %% [markdown]
# <img src ="https://www.pinclipart.com/picdir/middle/395-3959661_youtube-subscribe-chanell-png-image-youtube-subscribe-logo.png">

# %% [markdown]
# The other way to scrab the image to direct request and use url in requests.get method.

# %%
image_link = requests.get("https://www.pinclipart.com/picdir/middle/395-3959661_youtube-subscribe-chanell-png-image-youtube-subscribe-logo.png")

# %%
image_link.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00CC)\x03p\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\
# ...

# %% [markdown]
# this is the row content of the actual image or binary file this is the computer way to representing the image what a image look like.

# %%
#image_link.content

# %%
f = open("my_computer_image.jpg","wb")

# %%
f.write(image_link.content)
# Out:
# 93693

# %%
f.close()

# %% [markdown]
# the image is save on this folder where you put this file if the image is not in the computer then put the whole url in the .jpg method.
#
#
# this is the example of downloading the image now move to next one.

# %% [markdown]
# # Working with Multiple Pages and Items

# %% [markdown]
# we have seen how to grab elements one at a time, but realistically, we want to be able to grab multiple elements, most likely across multiple pages.
#
# We will use a site specifically designed to practice web scraping: https://www.amazon.in/Books/b/?ie=UTF8&node=976389031&ref_=nav_cs_books
# we will practice grabbing elements across multipale pages.

# %%
"http://books.toscrape.com/catalogue/page-2.html"
# Out:
# 'https://books.toscrape.com/catalogue/page-2.htmll'

# %%
#GOAL : Get the title of every book with a 2 star rating

# %%
"http://books.toscrape.com/catalogue/page-3.html"
# Out:
# 'https://books.toscrape.com/catalogue/page-3.html'

# %%
base_url ="http://books.toscrape.com/catalogue/page-{}.html"

# %%
page_num = 12
base_url.format(page_num)
# Out:
# 'http://books.toscrape.com/catalogue/page-12.html'

# %%
res = requests.get(base_url.format(1))

# %%
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
products = soup.select(".product_pod")

# %%
example =products[0]

# %%
example
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
example.select(".star-rating.Three")
# Out:
# [<p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>]

# %%
example.select("a")
# Out:
# [<a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>,
#  <a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>]

# %%
example.select("a")[1]["title"]
# Out:
# 'A Light in the Attic'

# %%
authors = set()
for name in Soup.select(".author"):
    authors.add(name.text)

# %%
authors
# Out:
# {'Albert Einstein',
#  'André Gide',
#  'Eleanor Roosevelt',
#  'J.K. Rowling',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Steve Martin',
#  'Thomas A. Edison'}

# %%
Soup.select(".text")
# Out:
# [<span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>,
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>,
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>,
#  <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>,
#  <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>,
#  <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>,
# ...

# %%
quotes = []
for name in Soup.select('.text')
qoutes.append(quote.text)
# Out:
#   File "<ipython-input-26-5c647e45a13c>", line 2
#     for name in Soup.select('.text')
#                                     ^
# SyntaxError: invalid syntax

# %%
quotes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1115ebbe0035> in <module>
# ----> 1 quotes
#
# NameError: name 'quotes' is not defined

# %% [markdown]
# Task : Inspect the site and use Beautiful soup to extract the top tags from the requests text shown on the top right from the home page (e.g love, Inspirational, life etc...) HINT : Keep in mind there are also tags underneath each quote, try to find a class only present in the top right tags. perhaps check the span.

# %%
for item in Soup.select('.tag-item'):
    print(item.text)

# %% [markdown]
# Task: Notice how there is more than one page. and subsequent pages look like this http://quotes.toscrape.com/page/2/. use what you know about for loops and string concatenation to loop through all the pages and get all the unique authors on the website. keep in mind there are many ways to achieve this, also note that you will need to somehow figure out how to check that your loop is on the last page with quotes.
